# %% [markdown]
# Esta historia comenzó cuando nuestro profesor de Introducción a la Ciencia de Datos (ICD) nos orientó un trabajo: realizar un análisis de alguna problemática de la economía cubana a partir de datos. En ese momento pensé: “Esto va a ser pesado”. No imaginaba lo mucho que me iba a marcar.

# %%
import main

# %% [markdown]
# Al final me decidí por estudiar a los jubilados . Me daba curiosidad cómo sería vivir la vejez en medio de la crisis económica del país. Quería analizar  si el poder adquisitivo de ese segmento de la población es relativamente viable con los precios que existen actualmente en el mercado. Pero antes de lanzarme a buscar datos, me puse a armar la estructura de mis JSON donde iba a guardar la información de las mipymes, para eso selecione y organize los siguientes indicadores.

# %%
{
  "localizacion": "",
  "servicio_a_domicilio": {
    "valor": True
  },
  "productos": [
    {
      "id": 1,
      "nombre": "Toallitas húmedas",
      "precio": 0.00,
      "unidad de medida":0,
      "categoria": "Higiene",
      "marca": "",
      "disponible": True,
      "descuento": 0.0
    },
    {
      "id": 2,
      "nombre": "Pañales",
      "precio": 0.00,
      "unidad de medida":0,
      "categoria": "Higiene",
      "marca": "",
      "disponible": True,
      "descuento": 0.0
    },
    {
      "id": 3,
      "nombre": "Pan",
      "precio": 0.00,
      "unidad de medida":0,
      "categoria": "alimentos",
      "marca": "",
      "disponible": True,
      "descuento": 0.0
    },
    {
      "id": 4,
      "nombre": "Leche",
      "precio": 0.00,
      "unidad de medida":0,
      "categoria": "alimentos",
      "marca": "",
      "disponible": True,
      "descuento": 0.0
    },
    {
      "id": 5,
      "nombre": "yogurt",
      "precio": 0.00,
      "unidad de medida":0,
      "categoria": "alimentos",
      "marca": "",
      "disponible": True,
      "descuento": 0.0
    },
    {
      "id": 6,
      "nombre": "pollo",
      "precio": 0.00,
      "unidad de medida":0,
      "categoria": "alimentos",
      "marca": "",
      "disponible": True,
      "descuento": 0.0
    },
    {
      "id": 7,
      "nombre": "picadillo",
      "precio": 0.00,
      "unidad de medida":0,
      "categoria": "alimentos",
      "marca": "",
      "disponible": True,
      "descuento": 0.0
    },
    {
      "id": 8,
      "nombre": "huevo",
      "precio": 0.00,
      "unidad de medida":0,
      "categoria": "alimentos",
      "marca": "",
      "disponible": True,
      "descuento": 0.0
    },
    {
      "id": 9,
      "nombre": "queso",
      "precio": 0.00,
      "unidad de medida":0,
      "categoria": "alimentos",
      "marca": "",
      "disponible": True,
      "descuento": 0.0
    },
    {
      "id": 10,
      "nombre": "sopas",
      "precio": 0.00,
      "unidad de medida":0,
      "categoria": "alimentos",
      "marca": "",
      "disponible": True,
      "descuento": 0.0
    },
    {
      "id": 11,
      "nombre": "arroz",
      "precio": 0.00,
      "unidad de medida":0,
      "categoria": "alimentos",
      "marca": "",
      "disponible": True,
      "descuento": 0.0
    },
    {
      "id": 12,
      "nombre": "frijoles",
      "precio": 0.00,
      "unidad de medida":0,
      "categoria": "alimentos",
      "marca": "",
      "disponible": True,
      "descuento": 0.0
    },
    {
      "id": 13,
      "nombre": "aceite",
      "precio": 0.00,
      "unidad de medida":0,
      "categoria": "alimentos",
      "marca": "",
      "disponible": True,
      "descuento": 0.0
    },{
      "id": 14,
      "nombre": "cereales",
      "precio": 0.00,
      "unidad de medida":0,
      "categoria": "alimentos",
      "marca": "",
      "disponible": True,
      "descuento": 0.0
    },
    {
      "id": 15,
      "nombre": "galletas integrales",
      "precio": 0.00,
      "unidad de medida":0,
      "categoria": "alimentos",
      "marca": "",
      "disponible": True,
      "descuento": 0.0
    }
    ]
}
# Out:
# {'localizacion': '',
#  'servicio_a_domicilio': {'valor': True},
#  'productos': [{'id': 1,
#    'nombre': 'Toallitas húmedas',
#    'precio': 0.0,
#    'unidad de medida': 0,
#    'categoria': 'Higiene',
#    'marca': '',
#    'disponible': True,
#    'descuento': 0.0},
#   {'id': 2,
#    'nombre': 'Pañales',
#    'precio': 0.0,
#    'unidad de medida': 0,
#    'categoria': 'Higiene',
#    'marca': '',
#    'disponible': True,
#    'descuento': 0.0},
#   {'id': 3,
#    'nombre': 'Pan',
#    'precio': 0.0,
#    'unidad de medida': 0,
#    'categoria': 'alimentos',
#    'marca': '',
#    'disponible': True,
#    'descuento': 0.0},
#   {'id': 4,
#    'nombre': 'Leche',
#    'precio': 0.0,
#    'unidad de medida': 0,
#    'categoria': 'alimentos',
#    'marca': '',
#    'disponible': True,
#    'descuento': 0.0},
#   {'id': 5,
#    'nombre': 'yogurt',
#    'precio': 0.0,
#    'unidad de medida': 0,
#    'categoria': 'alimentos',
#    'marca': '',
#    'disponible': True,
# ...

# %% [markdown]
# Después de tener mi estructura y saber los indicadores a analizar. Me faltaba la parte más esencial: conseguir todos los datos. Así que comence la recogida de datos con la ayuda de miembros de mi familia encontrando diversos obstaculos :
# 1-La poca comprension de los diferentes gestores de las mipymes visitadas
# 2-Dificultades en la transportación de una mipyme a otra
# 3-La complejidad en el procesamiento en la información obtenida

# %% [markdown]
# Mediante la información que pude obtener selecione las graficas que queria utilizar.La primera es una gráfica  que mostraba el precio promedio de los productos en comparacion a la pensión mínima de un jubilado resultando que el poder adquisitivo de los jubilados esta muy por debajo de los precios existentes en el mercado teniendo estos una situacion muy compleja.

# %%
main.promedio(producto_buscado="pollo")
# Out:
# 4165

# %%
diccionario = {
    "Pan": main.promedio("Pan"),
    "Leche": main.promedio("Leche"),
    "Toallitas húmedas":main.promedio("Toallitas húmedas"),
    "Pañales":main.promedio("Pañales"),
    "yogurt":main.promedio("yogurt"),
    "pollo":main.promedio("pollo"),
    "picadillo":main.promedio("picadillo"),
    "huevo":main.promedio("huevo"),
    "queso":main.promedio("queso"),
    "sopas":main.promedio("sopas"),
    "arroz":main.promedio("arroz"),
    "frijoles":main.promedio("frijoles"),
    "aceite":main.promedio("aceite"),
    "cereales":main.promedio("cereales"),
    "galletas":main.promedio("galletas")
}

# %%
main.grafico_precio_promedio_vs_pension_minima(diccionario)

# %% [markdown]
# Desde el principio pensé en lo valioso que es el servicio a domicilio. Imaginaba a los jubilados y a las personas mayores con limitaciones motoras u otras , que les impide  comprar. Para ellos, recibir los productos en casa ,no es un lujo, es una necesidad. Por eso me propuse indagar, cuántas mipymes ofrecían este servicio y cuántas no, descubriendo asi quién realmente piensa en esas personas.

# %%
main.grafico_servicio_domicilio()

# %% [markdown]
# También me llamó la atención cómo un mismo producto podía variar tanto de precio según la marca o la mipyme donde se vendiera.
# Pensé en el caso del pollo, un alimento habitual en la mesa de muchas familias.
# No es lo mismo comprarlo en una tienda con marca reconocida que en otra sin marca, y esas diferencias impactan directamente en el bolsillo de los jubilados.
# Por eso decidí analizar los precios de cada marca y compararlos para ver observar las variaciones entre ellos, como se observa  a continuación.

# %%
main.grafico_precios_marca_producto(producto_buscado="pollo")

# %% [markdown]
# Esta gráfica nos muestra la variación de precios de un producto básico, el huevo en toda la muestra de datos.Donde decidí compararlo con la pension promedio de un jubilado donde estos los lleve de cup a usd utilizando el tipo de cambio del mercado informal, este cambio fue realizado debido que aunque las transacciones son en cup la economía opera con el dolar como referencia para costos y precios por lo que el valor real de los bienes , los costos de importación y  operación de las mipymes están estructurados en referencia al dólar.La variacion de precios se debe a facotres como si lo importan directamente o son revendedores ademas de la ubicación.No existe un precio único sino un rango de este por las condiciones del mercado como se muestra a continuación.

# %%
main.comparacion_precio_mipymes(producto_comparar="huevo")

# %% [markdown]
# Cuando caminaba por La Habana me di cuenta de que en las mipymes no solo importaba el precio, sino también la cantidad de productos disponibles en cada lugar.
# A veces entrábamos a una mipyme y apenas había unos pocos productos en los estantes, mientras que en otra la variedad era mucho mayor.
# Pensé en los jubilados y en cualquier persona que depende de encontrar lo básico: si una mipyme tiene pocas ofertas, no importa que los precios sean buenos, simplemente no hay qué comprar.
# Por eso decidí graficar cuántos productos estaban realmente en ofertas en cada una de ellas, para mostrar cómo cambia la varia de un lugar a otro.

# %%
main.grafico_disponibilidad_mypimes()

# %% [markdown]
# Después de recorrer las calles, visitar las mipymes, recolectar precios y transformar todo en datos y gráficas, entendí que este proyecto fue mucho más que números.
# Cada archivo JSON era como una pequeña ventana a la realidad de la ciudad: tiendas con estantes llenos, otras casi vacías, algunas con servicio a domicilio y otras sin esa opción tan necesaria para los jubilados.
# Al comparar el poder adquisitivo de los jubilados con los precios de los productos , descubrí lo duro que puede ser sobrevivir con tan poco, cuando productos:como el arroz, el pollo y los demás que analicé se acercan peligrosamente a ese límite.
# Las gráficas me mostraron desigualdades claras: marcas que encarecen lo esencial, mipymes con más variedad que otras, y un mercado que refleja las dificultades cotidianas de los jubilados.
# Pero más allá de los hallazgos, me quedo con la experiencia de caminar por La Habana, compartir anécdotas con mis amigos y aprender que detrás de cada número hay personas, historias y realidades que no se pueden ignorar.
# Lo que empezó como una tarea académica terminó siendo un viaje personal, un cuento de datos y emociones que me enseñó a mirar la ciencia de datos desde la vida misma.
